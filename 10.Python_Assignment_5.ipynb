# %% [markdown]
# 1. Who developed Python Programming Language?
#
# Ans-Guio Von Rossum
#
# 2. Which type of Programming does Python support?
#
# Ans-It supports object oriented,procedural,functional programming
#
# 3. Is Python case sensitive when dealing with identifiers?
#
# Ans-Yes,it is case sensitive when dealing with identifiers.For example,'var' and 'Var' are 2 different things.
#
# 4. What is the correct extension of the Python file?
#
# Ans-.py
#
# 5. Is Python code compiled or interpreted?
#
# Ans-It is interpreted means reads and executes the code line by line without compiling it into machine code.
#
# 6. Name a few blocks of code used to define in Python language?
#
# Ans-functions,classes and modules
#
# 7.State a character used to give single-line comments in Python
#
# Ans-#
#
# 8. Mention functions which can help us to find the version of python that we are currently working on?
#
# Ans-'sys' module and its functions are sys.version and sys.version_info
#
# 9. Python supports the creation of anonymous functions at runtime, using a construct called
#
# Ans-lambda
#
# 10. What does pip stand for python?
#
# Ans-pip installs packages
#
# 11. Mention a few built-in functions in python?
#
# Ans=print(), len(), range(), type(), max(), min(), sum(), abs(), round(), input(), open(), dir(), help(), etc.
#
# 12. What is the maximum possible length of an identifier in Python?
#
# ANs=It is not fixed.It should be a atmost limit a 79 characters for readability
#
# 13. What are the benefits of using Python?
#
# Ans-Because of its simplicity,versality and easy to understand.It is widely used in like scientific computing and machine learning etc.
# 14. How is memory managed in Python?
#
# Ans-It is done automatically using a garbage collector that frees up memory when objects are no longer in use.
#
# 15. How to install Python on Windows and set path variables?
#
# Ans-To install Python on Windows, download the latest version from the official website and run the installer. During the installation process, make sure to select the option to add Python to the system path, which will allow you to access Python from the command line. After installation, you can set the path variables by adding the Python installation directory to the PATH environment variable
#
# 16. Is indentation required in python?
#
# Ans-Yes, indentation is required in Python as it is used to indicate the block of code that belongs to a particular control structure such as a function, class, loop, or conditional statement. The standard indentation in Python is four spaces, and it is recommended to use spaces instead of tabs for indentation.
